# %%
import matplotlib.pyplot as plt

from skimage import exposure, io, data, feature

## image sources to compare;
airplane_image = 'plane_data/cropped_images/2017-08-25T23+24+13_390Z.png'
cat_image = 'plane_data/cropped_images/_cat.jpeg'
astronaut_image = data.astronaut() #https://scikit-image.org/docs/dev/api/skimage.data.html#skimage.data.astronaut

## Change the img source to view here
my_img = astronaut_image

fd, hog_image = feature.hog(my_img, orientations=10, pixels_per_cell=(16, 16),
                    cells_per_block=(3, 3), visualize=True, multichannel=True)

#fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4), sharex=True, sharey=True)

# ax1.axis('off')
# ax1.imshow(image, cmap=plt.cm.gray)
# ax1.set_title('Input image')
# io.imshow(image, cmap=plt.cm.gray)
# Rescale histogram for better display
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 10))

# ax2.axis('off')
io.imshow(hog_image_rescaled)
#ax2.set_title('Histogram of Oriented Gradients')
# plt.show()
